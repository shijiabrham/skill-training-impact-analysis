# %% [markdown]
# # Step 1 : Importing the libraries and opening the datafile

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
print("Ready!")
# Out:
# Ready!

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/RBL_Data_dirty.csv')
#df  = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Data/RBL_data_dirty.xlsx", sheet_name="RBL")

print("File loaded!")

print(f" number of rows and columns {df.shape}")
print(f"First 10 rows \n {df.head(10)} \n\n")
print(f"Last 10 rows \n {df.tail(10)}\n\n")
print(f" Info {df.info()} \n \n")
print(f" Statistical values {df.describe()}\n\n")
print(f"missing values \n {df.isnull().sum()}")
# Out:
# File loaded!
#  number of rows and columns (650, 25)
# First 10 rows
#     Sr. No.       Year          Batch_No Batch_Start_Date Batch_End_Date  \
# 0        1  2020-2021  PTF/RBL/BFSI/001         9/7/2020     10/12/2020
# 1        2  2020-2021  PTF/RBL/BFSI/001         9/7/2020     10/12/2020
# 2        3  2020-2021  PTF/RBL/BFSI/001         9/7/2020     10/12/2020
# 3        4  2020-2021  PTF/RBL/BFSI/001         9/7/2020     10/12/2020
# 4        5  2020-2021  PTF/RBL/BFSI/001         9/7/2020     10/12/2020
# 5        6  2020-2021  PTF/RBL/BFSI/001         9/7/2020     10/12/2020
# 6        7  2020-2021  PTF/RBL/BFSI/001         9/7/2020     10/12/2020
# 7        8  2020-2021  PTF/RBL/BFSI/001         9/7/2020     10/12/2020
# 8        9  2020-2021  PTF/RBL/BFSI/001         9/7/2020     10/12/2020
# 9       10  2020-2021  PTF/RBL/BFSI/001         9/7/2020     10/12/2020
#
#       Mobile   Name_of_Candidate  Gender             Fathers_Name  \
# ...

# %% [markdown]
# Step 2 :
# Opening the data file and checking how big is the data.
# checking the top and bottom rows for data.
# Understanding the structure of the dataset and the datatypes

# %% [markdown]
# ## Step 3 : Taking a look at the top 5 rows and bottom 5 ros

# %%
print(f" top 5 rows : {df.head()}")
print(f"bottom 5 rows :{df.tail()}")
# Out:
#  top 5 rows :    Sr. No.       Year          Batch_No Batch_Start_Date Batch_End_Date  \
# 0        1  2020-2021  PTF/RBL/BFSI/001         9/7/2020     10/12/2020
# 1        2  2020-2021  PTF/RBL/BFSI/001         9/7/2020     10/12/2020
# 2        3  2020-2021  PTF/RBL/BFSI/001         9/7/2020     10/12/2020
# 3        4  2020-2021  PTF/RBL/BFSI/001         9/7/2020     10/12/2020
# 4        5  2020-2021  PTF/RBL/BFSI/001         9/7/2020     10/12/2020
#
#       Mobile   Name_of_Candidate  Gender             Fathers_Name  \
# 0  7380853548  SHWETA SRIVASTAVA  Female        Ramesh Srivastava
# 1  9415741361  DIKSHA SRIVASTAVA  Female  Hari Shankar Srivastava
# 2  9140185717              KIRAN  Female           Shiv Mohan Lal
# 3  9161344064      PREETI DHANUK  Female           Shiv Mohan Lal
# 4  8009274430       SMITA GAUTAM  Female            Kamlesh Kumar
#
#            Joining_Status  ... After_training_new_skill_dev_course_joined  \
# ...

# %% [markdown]
# Step 4 :
# 1. Checking for missing values.
# 2. checking for duplicates
# 3. checking uniques values of employers

# %%
print(f" Duplicated : {df.duplicated().sum()}\n")
print(f" Missing values : {df.isnull().sum()}\n")
print(f" Unique values : {df.nunique()}\n")
print(f" Unique values : {df['Employer_Name '].unique()}\n")
# Out:
#  Duplicated : 0
#
#  Missing values : Sr. No.                                         0
# Year                                            0
# Batch_No                                        0
# Batch_Start_Date                                0
# Batch_End_Date                                  0
# Mobile                                          0
# Name_of_Candidate                               0
# Gender                                          0
# Fathers_Name                                    0
# Joining_Status                                  0
# If_not_joined_reasons                         552
# Opted_education                               611
# Employer_Name                                  98
# Placement_Date                                 99
# Salary                                         99
# After_training_new_skill_dev_course_joined      0
# If_yes_Name_of_the_course                     650
# currently_working_in_BFSI                      98
# ...

# %% [markdown]
# # Step 5: Pre-proessing the data to appropriate data type

# %%
df.columns = df.columns.str.strip()
# Converting object to date
df["Batch_Start_Date"]= pd.to_datetime(df["Batch_Start_Date"])
df["Batch_End_Date"]= pd.to_datetime(df["Batch_End_Date"])
df["Placement_Date"]= pd.to_datetime(df["Placement_Date"])
df["If_not_working_last_day_of_job"] = pd.to_datetime(df["If_not_working_last_day_of_job"])
# Converting Integer to String
df["Mobile"]=df["Mobile"].astype(str)
#df["If_yes_Name_of_the_course"]=df["If_yes_Name_of_the_course"].to_string()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 25 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Sr. No.                                     650 non-null    int64
#  1   Year                                        650 non-null    object
#  2   Batch_No                                    650 non-null    object
#  3   Batch_Start_Date                            650 non-null    datetime64[ns]
#  4   Batch_End_Date                              650 non-null    datetime64[ns]
#  5   Mobile                                      650 non-null    object
#  6   Name_of_Candidate                           650 non-null    object
#  7   Gender                                      650 non-null    object
#  8   Fathers_Name                                650 non-null    object
# ...

# %% [markdown]
# # Step 6 : Writing the dataset to the clean dataset

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/Data/RBL_Data_cleaned_s.csv', index=False)
#df.to_excel('/content/drive/MyDrive/Colab Notebooks/Data/RBL_data_cleaned.xlsx', index=False)

print("Cleaned DataFrame saved to 'RBL_data_cleaned.csv' in your Google Drive.")
# Out:
# Cleaned DataFrame saved to 'RBL_data_cleaned.csv' in your Google Drive.

# %% [markdown]
# Step 7 : Opening the cleaned dataset

# %%
#df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/RBL_Data_cleaned.csv')
df  = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Data/RBL_data_cleaned.xlsx")

print("File loaded!")


df.info()
# Out:
# File loaded!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Sr. No.                              650 non-null    int64
#  1   Year                                 650 non-null    object
#  2   Batch No                             650 non-null    object
#  3   Batch Start Date                     650 non-null    datetime64[ns]
#  4   Batch End Date                       650 non-null    datetime64[ns]
#  5   Mobile                               650 non-null    int64
#  6   Name of Candidate                    650 non-null    object
#  7   Gender                               650 non-null    object
#  8   Father's Name                        650 non-null    object
#  9   Joining Status                       650 non-null    object
# ...

# %%
shape[0]
